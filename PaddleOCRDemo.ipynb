# %%
# !python3 -m pip install paddlepaddle-gpu
# Out:
# Collecting paddlepaddle-gpu
#   Downloading paddlepaddle_gpu-2.5.2-cp310-cp310-manylinux1_x86_64.whl (542.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.5/542.5 MB 3.2 MB/s eta 0:00:00
# Collecting httpx (from paddlepaddle-gpu)
#   Downloading httpx-0.25.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (9.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (4.4.2)
# Collecting astor (from paddlepaddle-gpu)
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle-gpu) (3.20.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (2023.7.22)
# Collecting httpcore (from httpx->paddlepaddle-gpu)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle-gpu) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle-gpu) (1.1.3)
# Collecting h11<0.15,>=0.13 (from httpcore->httpx->paddlepaddle-gpu)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: h11, astor, httpcore, httpx, paddlepaddle-gpu
# Successfully installed astor-0.8.1 h11-0.14.0 httpcore-1.0.2 httpx-0.25.1 paddlepaddle-gpu-2.5.2

# %%
# !pip install "paddleocr>=2.0.1"
# Out:
# Collecting paddleocr>=2.0.1
#   Downloading paddleocr-2.7.0.3-py3-none-any.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.7/465.7 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (2.0.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.19.3)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (0.4.0)
# Collecting pyclipper (from paddleocr>=2.0.1)
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 42.4 MB/s eta 0:00:00
# Collecting lmdb (from paddleocr>=2.0.1)
#   Downloading lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 36.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.66.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (1.23.5)
# Collecting visualdl (from paddleocr>=2.0.1)
#   Downloading visualdl-2.5.3-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 88.4 MB/s eta 0:00:00
# Collecting rapidfuzz (from paddleocr>=2.0.1)
#   Downloading rapidfuzz-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 84.6 MB/s eta 0:00:00
# Collecting opencv-python<=4.6.0.66 (from paddleocr>=2.0.1)
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 7.5 MB/s eta 0:00:00
# Collecting opencv-contrib-python<=4.6.0.66 (from paddleocr>=2.0.1)
#   Downloading opencv_contrib_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 MB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (3.0.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.9.3)
# Collecting premailer (from paddleocr>=2.0.1)
#   Downloading premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (3.1.2)
# Collecting attrdict (from paddleocr>=2.0.1)
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting PyMuPDF<1.21.0 (from paddleocr>=2.0.1)
#   Downloading PyMuPDF-1.20.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 96.4 MB/s eta 0:00:00
# Collecting Pillow>=10.0.0 (from paddleocr>=2.0.1)
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 122.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (6.0.1)
# Collecting python-docx (from paddleocr>=2.0.1)
#   Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 36.1 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.11.2)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr>=2.0.1) (4.44.3)
# Collecting fire>=0.3.0 (from paddleocr>=2.0.1)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdf2docx (from paddleocr>=2.0.1)
#   Downloading pdf2docx-0.5.6-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.4/148.4 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr>=2.0.1) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr>=2.0.1) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr>=2.0.1) (2.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr>=2.0.1) (1.11.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr>=2.0.1) (3.7.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr>=2.0.1) (2.31.6)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr>=2.0.1) (23.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->paddleocr>=2.0.1) (1.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr>=2.0.1) (4.5.0)
# Collecting cssselect (from premailer->paddleocr>=2.0.1)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting cssutils (from premailer->paddleocr>=2.0.1)
#   Downloading cssutils-2.9.0-py3-none-any.whl (398 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.5/398.5 kB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from premailer->paddleocr>=2.0.1) (2.31.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from premailer->paddleocr>=2.0.1) (5.3.2)
# Collecting bce-python-sdk (from visualdl->paddleocr>=2.0.1)
#   Downloading bce_python_sdk-0.8.96-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: flask>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from visualdl->paddleocr>=2.0.1) (2.2.5)
# Collecting Flask-Babel>=3.0.0 (from visualdl->paddleocr>=2.0.1)
#   Downloading flask_babel-4.0.0-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.10/dist-packages (from visualdl->paddleocr>=2.0.1) (3.20.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from visualdl->paddleocr>=2.0.1) (1.5.3)
# Collecting rarfile (from visualdl->paddleocr>=2.0.1)
#   Downloading rarfile-4.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from visualdl->paddleocr>=2.0.1) (5.9.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (8.1.7)
# Requirement already satisfied: Babel>=2.12 in /usr/local/lib/python3.10/dist-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr>=2.0.1) (2.13.1)
# Requirement already satisfied: pytz>=2022.7 in /usr/local/lib/python3.10/dist-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr>=2.0.1) (2023.3.post1)
# Collecting Pillow>=10.0.0 (from paddleocr>=2.0.1)
#   Downloading Pillow-10.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 120.5 MB/s eta 0:00:00
# Collecting pycryptodome>=3.8.0 (from bce-python-sdk->visualdl->paddleocr>=2.0.1)
#   Downloading pycryptodome-3.19.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 98.9 MB/s eta 0:00:00
# Requirement already satisfied: future>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from bce-python-sdk->visualdl->paddleocr>=2.0.1) (0.18.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->premailer->paddleocr>=2.0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->premailer->paddleocr>=2.0.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->premailer->paddleocr>=2.0.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->premailer->paddleocr>=2.0.1) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask>=1.1.1->visualdl->paddleocr>=2.0.1) (2.1.3)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116933 sha256=680f308b432f89a7dd8c1c588bdc444930aa7b3b7de1a77659f836ccbc703349
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, rarfile, rapidfuzz, python-docx, PyMuPDF, pycryptodome, Pillow, opencv-python, opencv-contrib-python, fire, cssutils, cssselect, attrdict, premailer, pdf2docx, bce-python-sdk, Flask-Babel, visualdl, paddleocr
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.8.0.76
#     Uninstalling opencv-contrib-python-4.8.0.76:
#       Successfully uninstalled opencv-contrib-python-4.8.0.76
# Successfully installed Flask-Babel-4.0.0 Pillow-10.0.1 PyMuPDF-1.20.2 attrdict-2.0.1 bce-python-sdk-0.8.96 cssselect-1.2.0 cssutils-2.9.0 fire-0.5.0 lmdb-1.4.1 opencv-contrib-python-4.6.0.66 opencv-python-4.6.0.66 paddleocr-2.7.0.3 pdf2docx-0.5.6 premailer-3.10.0 pyclipper-1.3.0.post5 pycryptodome-3.19.0 python-docx-1.1.0 rapidfuzz-3.5.2 rarfile-4.1 visualdl-2.5.3

# %%
# !wget http://nz2.archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb

# !sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb
# Out:
# --2023-11-20 06:01:47--  http://nz2.archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb
# Resolving nz2.archive.ubuntu.com (nz2.archive.ubuntu.com)... 91.189.91.82, 91.189.91.81, 185.125.190.39, ...
# Connecting to nz2.archive.ubuntu.com (nz2.archive.ubuntu.com)|91.189.91.82|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-11-20 06:01:47 ERROR 404: Not Found.
#
# dpkg: error: cannot access archive 'libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb': No such file or directory

# %%
from paddleocr import PaddleOCR,draw_ocr
# Paddleocr supports Chinese, English, French, German, Korean and Japanese.
# You can set the parameter `lang` as `ch`, `en`, `fr`, `german`, `korean`, `japan`
# to switch the language model in order.
ocr = PaddleOCR(use_angle_cls=True, lang='en') # need to run only once to download and load model into memory
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:08<00:00, 492kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [00:14<00:00, 684kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:06<00:00, 319kiB/s]
# [2023/11/20 06:02:51] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
img_path = '/content/invoice.png'

img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     638     try:
# --> 639         rawmode = RAWMODE[im.mode]
#     640     except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in _repr_image(self, image_format, **kwargs)
#     642         try:
# --> 643             self.save(b, image_format, **kwargs)
#     644         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2412         try:
# -> 2413             save_handler(self, fp, filename)
#    2414         except Exception:
#
# /usr/local/lib/python3.10/dist-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     641         msg = f"cannot write mode {im.mode} as JPEG"
# --> 642         raise OSError(msg) from e
#     643
#
# OSError: cannot write mode RGBA as JPEG
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in _repr_jpeg_(self)
#     659         :returns: JPEG version of the image as bytes
#     660         """
# --> 661         return self._repr_image("JPEG")
#     662
#     663     @property
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in _repr_image(self, image_format, **kwargs)
#     644         except Exception as e:
#     645             msg = f"Could not save to {image_format} for display"
# --> 646             raise ValueError(msg) from e
#     647         return b.getvalue()
#     648
#
# ValueError: Could not save to JPEG for display
# <PIL.Image.Image image mode=RGBA size=900x777>

# %%
img_path
# Out:
# '/content/invoice.png'

# %%
img
# Out:
# array([[[247, 242, 243, 255],
#         [249, 249, 249, 255],
#         [251, 251, 251, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[249, 244, 244, 255],
#         [250, 249, 249, 255],
#         [251, 251, 251, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[252, 248, 248, 255],
#         [252, 252, 252, 255],
#         [251, 252, 252, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]]], dtype=uint8)

# %%
# Run the ocr method on the ocr model
result = ocr.ocr(img_path)
# Out:
# [2023/11/20 06:14:22] ppocr DEBUG: dt_boxes num : 54, elapsed : 0.06097126007080078
# [2023/11/20 06:14:22] ppocr DEBUG: cls num  : 54, elapsed : 0.06356143951416016
# [2023/11/20 06:14:22] ppocr DEBUG: rec_res num  : 54, elapsed : 0.25881528854370117

# %%
result
# Out:
# [[[[[50.0, 48.0], [221.0, 48.0], [221.0, 58.0], [50.0, 58.0]],
#    ('This is a PDF rendering of an electronic Invoice', 0.9831034541130066)],
#   [[[738.0, 62.0], [793.0, 62.0], [793.0, 73.0], [738.0, 73.0]],
#    ('Page 1 of 1', 0.99710613489151)],
#   [[[111.0, 164.0], [178.0, 164.0], [178.0, 181.0], [111.0, 181.0]],
#    ('Invoice', 0.9972820281982422)],
#   [[[637.0, 172.0], [734.0, 172.0], [734.0, 204.0], [637.0, 204.0]],
#    ('BigCo', 0.9991458058357239)],
#   [[[665.0, 207.0], [707.0, 207.0], [707.0, 227.0], [665.0, 227.0]],
#    ('Inc.', 0.9984751343727112)],
#   [[[112.0, 285.0], [127.0, 288.0], [125.0, 300.0], [110.0, 297.0]],
#    ('TO', 0.9453378915786743)],
#   [[[325.0, 286.0], [353.0, 286.0], [353.0, 297.0], [325.0, 297.0]],
#    ('FROM', 0.998016357421875)],
#   [[[540.0, 285.0], [613.0, 285.0], [613.0, 296.0], [540.0, 296.0]],
#    ('INVOICE NUMBER', 0.9771126508712769)],
#   [[[111.0, 301.0], [186.0, 301.0], [186.0, 316.0], [111.0, 316.0]],
#    ('Test Corp', 0.9776608347892761)],
#   [[[325.0, 300.0], [398.0, 300.0], [398.0, 315.0], [325.0, 315.0]],
#    ('BigCo Inc', 0.9289891719818115)],
#   [[[539.0, 298.0], [584.0, 298.0], [584.0, 310.0], [539.0, 310.0]],
#    ('7578765', 0.9999278783798218)],
#   [[[111.0, 319.0], [205.0, 319.0], [205.0, 332.0], [111.0, 332.0]],
#    ('123 1234 George ST', 0.9907357096672058)],
#   [[[326.0, 319.0], [374.0, 319.0], [374.0, 330.0], [326.0, 330.0]],
#    ('500 3rd St', 0.9812539219856262)],
#   [[[112.0, 332.0], [179.0, 332.0], [179.0, 343.0], [112.0, 343.0]],
#    ('Test WI 53223', 0.934114396572113)],
#   [[[324.0, 330.0], [437.0, 329.0], [437.0, 343.0], [325.0, 344.0]],
#    ('San Francisco CA 94107', 0.9863349795341492)],
#   [[[539.0, 324.0], [591.0, 324.0], [591.0, 335.0], [539.0, 335.0]],
#    ('ISSUE DATE', 0.9799854159355164)],
#   [[[646.0, 324.0], [693.0, 324.0], [693.0, 335.0], [646.0, 335.0]],
#    ('CURRENCY', 0.9970231652259827)],
#   [[[112.0, 346.0], [173.0, 346.0], [173.0, 357.0], [112.0, 357.0]],
#    ('United States', 0.9999130964279175)],
#   [[[325.0, 345.0], [387.0, 345.0], [387.0, 356.0], [325.0, 356.0]],
#    ('United States', 0.9999215602874756)],
#   [[[539.0, 338.0], [578.0, 338.0], [578.0, 349.0], [539.0, 349.0]],
#    ('11/1/17', 0.999610424041748)],
#   [[[646.0, 337.0], [669.0, 337.0], [669.0, 349.0], [646.0, 349.0]],
#    ('USD', 0.9993834495544434)],
#   [[[114.0, 402.0], [180.0, 402.0], [180.0, 413.0], [114.0, 413.0]],
#    ('LINE ID ITEM ID', 0.9751566648483276)],
#   [[[209.0, 402.0], [266.0, 402.0], [266.0, 412.0], [209.0, 412.0]],
#    ('DESCRIPTION', 0.9984542727470398)],
#   [[[423.0, 400.0], [494.0, 400.0], [494.0, 411.0], [423.0, 411.0]],
#    ('QUANTITY UNIT', 0.957399308681488)],
#   [[[512.0, 400.0], [561.0, 400.0], [561.0, 410.0], [512.0, 410.0]],
#    ('UNIT PRICE', 0.9900823831558228)],
#   [[[608.0, 399.0], [629.0, 399.0], [629.0, 411.0], [608.0, 411.0]],
#    ('TAX', 0.9976956248283386)],
#   [[[651.0, 399.0], [754.0, 399.0], [754.0, 409.0], [651.0, 409.0]],
#    ('TOTAL USD EXCL.TAXES', 0.9535301327705383)],
#   [[[112.0, 423.0], [122.0, 423.0], [122.0, 434.0], [112.0, 434.0]],
#    ('1', 0.9924692511558533)],
#   [[[143.0, 421.0], [179.0, 421.0], [179.0, 435.0], [143.0, 435.0]],
#    ('Item A', 0.9986637234687805)],
#   [[[207.0, 421.0], [243.0, 421.0], [243.0, 435.0], [207.0, 435.0]],
#    ('Item A', 0.9993901252746582)],
#   [[[451.0, 417.0], [493.0, 419.0], [493.0, 434.0], [450.0, 432.0]],
#    ('20 pcs', 0.9320471286773682)],
#   [[[532.0, 415.0], [566.0, 418.0], [565.0, 433.0], [531.0, 431.0]],
#    ('10.00', 0.9975789785385132)],
#   [[[600.0, 415.0], [630.0, 418.0], [629.0, 433.0], [598.0, 431.0]],
#    ('7.6%', 0.9998477697372437)],
#   [[[720.0, 417.0], [757.0, 417.0], [757.0, 431.0], [720.0, 431.0]],
#    ('200.00', 0.9991336464881897)],
#   [[[112.0, 443.0], [122.0, 443.0], [122.0, 455.0], [112.0, 455.0]],
#    ('2', 0.9987748265266418)],
#   [[[142.0, 440.0], [179.0, 442.0], [178.0, 458.0], [141.0, 455.0]],
#    ('Item B', 0.9203020930290222)],
#   [[[208.0, 440.0], [243.0, 442.0], [242.0, 458.0], [207.0, 455.0]],
#    ('Item B', 0.9979851245880127)],
#   [[[452.0, 438.0], [492.0, 440.0], [492.0, 456.0], [451.0, 453.0]],
#    ('10 pcs', 0.9894404411315918)],
#   [[[532.0, 436.0], [566.0, 438.0], [565.0, 454.0], [531.0, 451.0]],
#    ('30.00', 0.9972696304321289)],
#   [[[600.0, 438.0], [630.0, 438.0], [630.0, 453.0], [600.0, 453.0]],
#    ('7.6%', 0.9996259212493896)],
#   [[[720.0, 437.0], [757.0, 437.0], [757.0, 452.0], [720.0, 452.0]],
#    ('300.00', 0.9991776943206787)],
#   [[[365.0, 465.0], [463.0, 465.0], [463.0, 490.0], [365.0, 490.0]],
#    ('1S usD', 0.7504175305366516)],
#   [[[498.0, 465.0], [583.0, 465.0], [583.0, 476.0], [498.0, 476.0]],
#    ('Subtotal excl taxes', 0.9998827576637268)],
#   [[[719.0, 461.0], [757.0, 461.0], [757.0, 476.0], [719.0, 476.0]],
#    ('500.00', 0.9987300038337708)],
#   [[[109.0, 481.0], [268.0, 471.0], [270.0, 499.0], [111.0, 509.0]],
#    ('+3IlemC', 0.8125823736190796)],
#   [[[497.0, 478.0], [625.0, 478.0], [625.0, 491.0], [497.0, 491.0]],
#    ('US Tax 7.6% of 500.00 USD', 0.9790696501731873)],
#   [[[725.0, 476.0], [757.0, 476.0], [757.0, 490.0], [725.0, 490.0]],
#    ('38.00', 0.998265266418457)],
#   [[[497.0, 498.0], [568.0, 498.0], [568.0, 512.0], [497.0, 512.0]],
#    ('Total USD', 0.9438192844390869)],
#   [[[708.0, 496.0], [756.0, 496.0], [756.0, 511.0], [708.0, 511.0]],
#    ('538.00', 0.9988104701042175)],
#   [[[497.0, 513.0], [599.0, 513.0], [599.0, 526.0], [497.0, 526.0]],
#    ('Total taxes USD 38.00', 0.9954138994216919)],
#   [[[112.0, 535.0], [213.0, 535.0], [213.0, 548.0], [112.0, 548.0]],
#    ('DELIVERY ADDRESS', 0.9658811688423157)],
#   [[[403.0, 534.0], [436.0, 534.0], [436.0, 548.0], [403.0, 548.0]],
#    ('NOTES', 0.9990383982658386)],
#   [[[112.0, 559.0], [180.0, 562.0], [179.0, 576.0], [111.0, 574.0]],
#    ('United States', 0.9913793206214905)],
#   [[[404.0, 562.0], [742.0, 560.0], [742.0, 572.0], [404.0, 573.0]],
#    ('Please note these items will be delivered according to our 3-days policy',
#     0.9907153248786926)]]]

# %%
len(result[0])
# Out:
# 54

# %%
for res in result:
    print(res[7][1])
# Out:
# ('INVOICE NUMBER', 0.9771126508712769)

# %%
for i in range(0,54):
    print(result[0][i][1][0])
# Out:
# This is a PDF rendering of an electronic Invoice
# Page 1 of 1
# Invoice
# BigCo
# Inc.
# TO
# FROM
# INVOICE NUMBER
# Test Corp
# BigCo Inc
# 7578765
# 123 1234 George ST
# 500 3rd St
# Test WI 53223
# San Francisco CA 94107
# ISSUE DATE
# CURRENCY
# United States
# United States
# 11/1/17
# USD
# LINE ID ITEM ID
# DESCRIPTION
# QUANTITY UNIT
# UNIT PRICE
# TAX
# TOTAL USD EXCL.TAXES
# 1
# Item A
# Item A
# 20 pcs
# 10.00
# 7.6%
# 200.00
# 2
# Item B
# Item B
# 10 pcs
# 30.00
# 7.6%
# 300.00
# 1S usD
# Subtotal excl taxes
# 500.00
# +3IlemC
# US Tax 7.6% of 500.00 USD
# 38.00
# Total USD
# 538.00
# Total taxes USD 38.00
# DELIVERY ADDRESS
# NOTES
# United States
# Please note these items will be delivered according to our 3-days policy
